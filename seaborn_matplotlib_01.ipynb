# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/NumPy_-_Seaborn/blob/main/seaborn_matplotlib_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Seaborn
# 1. Seaborn is a library mostly used for statistical plotting in Python.
# 2. It is built on top of Matplotlib and provides beautiful default styles and color palettes to make statistical plots more attractive.
#
# 3. We will be plotting a simple line plot using the iris dataset. Iris dataset contains five columns such as Petal Length, Petal Width, Sepal Length, Sepal Width and Species Type.
# 4. Iris is a flowering plant, the researchers have measured various features of the different iris flowers and recorded them digitally.

# %% [markdown]
# ![downloadirisds (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #9 Seaborn Datasets for Data Science + ML Beginners
# ![seaborn_datasets (1).jpg](data:image/jpeg;base64,...)

# %%
import seaborn as sns

data=sns.load_dataset("planets")

print(data.head())      # head() means top 5 records.....head(10)means top 10records
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
import seaborn as sns

data=sns.load_dataset("iris")

data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## sns.lineplot(x='',y='',data=name of data set)

# %%
import seaborn as sns

import matplotlib.pyplot as plt

datairis=sns.load_dataset("iris")

sns.lineplot(x='sepal_length',y='sepal_width',data=datairis)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## Setting the xlim and ylim

# %%
import seaborn as sns

import matplotlib.pyplot as plt

datairis=sns.load_dataset('iris')

sns.lineplot(x='sepal_length',y='sepal_width',data=datairis)

plt.xlim(5)         # values on x axis will start from 5

plt.show()

# %% [markdown]
# ## Customizing Seaborn Plots
#
# There are five themes available in Seaborn.
#
# 1. darkgrid
# 2. whitegrid
# 3. dark
# 4. white
# 5. ticks

# %%
import seaborn as sns

data=sns.load_dataset('iris')

sns.set_style('darkgrid')          # other 4 arguments .....whitegrid,dark,white,ticks

sns.lineplot(x='sepal_length',y='sepal_width',data=datairis)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
import seaborn as sns

import matplotlib.pyplot as plt

data=sns.load_dataset('iris')

sns.set_style('darkgrid')          # other 4 arguments .....whitegrid,dark,white,ticks

sns.lineplot(x='sepal_length',y='sepal_width',data=datairis)

plt.show()

# %% [markdown]
# ## Changing the figure Size

# %%
import seaborn as sns

import matplotlib.pyplot as plt

datairis=sns.load_dataset('iris')

plt.figure(figsize=(12,6))

sns.lineplot(x='sepal_length',y='sepal_width',data=datairis)

plt.show()

# %% [markdown]
# ## Removing the spines

# %%
sns.despine()
