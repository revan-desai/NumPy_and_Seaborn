# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/NumPy_and_Seaborn/blob/main/seaborn_matplotlib_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Violinplot
# It is similar to the boxplot except that it provides a higher, more advanced visualization and uses the kernel density estimation to give a better description about the data distribution. It is created using the violinplot() method.

# %%
import seaborn as sns

import matplotlib.pyplot as plt

datairis=sns.load_dataset('iris')

sns.violinplot(x='species',y='sepal_length',data=datairis)      # no complusion of having categorical value at x or y axis

plt.show()

# %% [markdown]
# ## stripplot()--> it basically creates a scatter plot based on the category. It is created using the stripplot() method.

# %%
import seaborn as sns

import matplotlib.pyplot as plt

datairis=sns.load_dataset('iris')

sns.stripplot(x='species',y='petal_width',data=datairis,palette='bright')   #palette ='muted','dark'   etc

plt.show()
# Out:
# <ipython-input-2-0bcd6356abe9>:7: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='species',y='petal_width',data=datairis,palette='bright')   #palette ='muted','dark'   etc

# %% [markdown]
# ## swarmplot()--> Swarmplot is very similar to the stripplot except the fact that the points are adjusted so that they do not overlap

# %%
import seaborn as sns

import matplotlib.pyplot as plt

sns.swarmplot(x='species',y='petal_width',data=datairis,palette='bright')

plt.show()
# Out:
# <ipython-input-3-e5a33b2435a5>:5: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='species',y='petal_width',data=datairis,palette='bright')
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## cat plot()

# %%
import seaborn as sns

import matplotlib.pyplot as plt

sns.catplot(x='species',y='petal_width',data=datairis,palette='bright')

plt.show()
# Out:
# <ipython-input-5-e3dd4691ca9b>:5: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x='species',y='petal_width',data=datairis,palette='bright')

# %% [markdown]
# ## displot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# loading dataset
data = sns.load_dataset("iris")

sns.displot(data['sepal_width'])
plt.show()

# %% [markdown]
# ## histogram()

# %%
x=[21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]

num_bin=5

n,bin,p=plt.hist(x,num_bin,facecolor='red',alpha=1)      # alpha(range 0 to 1) is how dark you want your color try changing its value. the color will get fade

# %% [markdown]
# ## jointplot()

# %%
datairis = sns.load_dataset("iris")

sns.jointplot(x='species', y='sepal_width', data=datairis)

plt.show()

# %% [markdown]
# ## pair plot()-->
# Pairplot represents pairwise relation across the entire dataframe and supports an additional argument called hue for categorical separation. What it does basically is create a jointplot between every possible numerical column and takes a while if the dataframe is really huge. It is plotted using the pairplot() method.

# %%
import seaborn as sns

import matplotlib.pyplot as plt

datairis=sns.load_dataset('iris')

sns.pairplot(data=datairis,hue='species')

plt.show()

# %% [markdown]
# ## KDE Plot
# KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable. We can also plot a single graph for multiple samples which helps in more efficient data visualization.

# %%
import seaborn as sns

import matplotlib.pyplot as plt

datairis=sns.load_dataset('iris')

sns.kdeplot(x='sepal_length',y='sepal_width',data=datairis)

plt.show()

# %% [markdown]
# ## Regression Plots
# there are two main functions that are used to draw linear regression models. These functions are lmplot(), and regplot(), are closely related to each other. They even share their core functionality.

# %% [markdown]
# lmplot
#
# lmplot() method can be understood as a function that basically creates a linear model plot. It creates a scatter plot with a linear fit on top of it.

# %%
import seaborn as sns

import matplotlib.pyplot as plt
datairis=sns.load_dataset('iris')
sns.lmplot(x='sepal_length',y='sepal_width',data=datairis)

plt.show()

# %%
datatips=sns.load_dataset('tips')
sns.lmplot(x='total_bill', y='tip', data=datatips)
plt.show()

# %% [markdown]
# ## Regplot
# regplot() method is also similar to lmplot which creates linear regression model.

# %%
sns.regplot(x='tip',y='total_bill',data=datatips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns

import matplotlib.pyplot as plt

hm=datatips.corr()

sns.heatmap(hm)

plt.show()
# Out:
# <ipython-input-56-95648d4d81a8>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hm=datatips.corr()
