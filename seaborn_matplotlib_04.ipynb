# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/NumPy_and_Seaborn/blob/main/seaborn_matplotlib_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Seaborn | Categorical Plots

# %% [markdown]
# ## barplot()

# %%
import seaborn as sns

import matplotlib.pyplot as plt

datatips=sns.load_dataset('tips')

sns.barplot(x='sex',y='total_bill',data=datatips)

                #OR

sns.barplot(x='sex',y='total_bill',data=datatips,palette='plasma')

plt.show()

# %% [markdown]
# ## count plot

# %%
import seaborn as sns

import matplotlib.pyplot as plt

datatips=sns.load_dataset('tips')

sns.countplot(x='sex',data=datatips)

plt.show()

# %% [markdown]
# ## box plot()
#
# A boxplot is sometimes known as the box and whisker plot.It shows the distribution of the quantitative data that represents the comparisons between variables. boxplot shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution i.e. the dots indicating the presence of outliers.

# %%
import seaborn as sns

import matplotlib.pyplot as plt

datatips=sns.load_dataset('tips')

sns.boxplot(x='day',y='total_bill',data=datatips,hue='smoker')

plt.show()

# %% [markdown]
# ![differents_parts_of_boxplot.png](data:image/png;base64,...)
