# %% [markdown]
# <a href="https://colab.research.google.com/github/revan-desai/NumPy_and_Seaborn/blob/main/seaborn_matplotlib_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

import matplotlib.pyplot as plt

sns.boxplot(x='time',y='tip',data=datatips,hue='sex')

plt.title('goodluck cafe')

plt.xlabel('mealtime')

plt.ylabel('tiptowaiter')
# Out:
# Text(0, 0.5, 'tiptowaiter')

# %%
import seaborn as sns

import matplotlib.pyplot as plt
datairis=sns.load_dataset('iris')

datairis1=datairis[datairis['species']=='virginica']
sns.scatterplot(x='petal_length',y='petal_width',data=datairis1)
plt.show()

# %%
sns.relplot(x='species',y='petal_width',data=datairis)

# %%
sns.relplot(x='sepal_width',y='species',data=datairis)

# %%
plot123=sns.FacetGrid(datatips,col='smoker')

plot123.map(plt.plot,'total_bill')

plt.show()
